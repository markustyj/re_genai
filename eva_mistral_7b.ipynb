# %%
from get_completion_evaluation import read_completion_list, process_completion_list
from get_completion_evaluation import process_ground_truth_list, load_csv_for_evaluation, get_evaluation_results

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # promise random binary

# %%
path_in = "./completions/mistral_7b/completion_promise_random_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.4177492137289758
# Precision: 0.4913151364764268
# Recall: 0.454520697167756
# ###########
#
#
# F1 Score: 0.4660033167495854
# Precision: 0.5130264648336937
# Recall: 0.49155773420479304
# ###########
#
#
# F1 Score: 0.5442222222222223
# Precision: 0.5574696928265427
# Recall: 0.5563725490196079
# ###########
#
#
# F1 Score: 0.5551111111111111
# Precision: 0.5685899188770395
# Recall: 0.5675381263616558
# ###########
#
#
# F1 Score: 0.5331465919701214
# Precision: 0.56
# Recall: 0.5509259259259259
# ###########
#
#
# F1 Score: 0.8692185007974482
# Precision: 0.8722222222222222
# Recall: 0.8831699346405228
# ###########
#
#
# F1 Score: 0.8844605475040257
# Precision: 0.8819776714513556
# Recall: 0.8913398692810457
# ###########

# %%
path_in = "./completions/mistral_7b/completion_promise_embedding_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.41144476438594085
# Precision: 0.48864734299516915
# Recall: 0.4498910675381264
# ###########
#
#
# F1 Score: 0.5547520199991072
# Precision: 0.5594117119540848
# Recall: 0.5618191721132897
# ###########
#
#
# F1 Score: 0.8047619047619048
# Precision: 0.8200483091787439
# Recall: 0.8247549019607843
# ###########
#
#
# F1 Score: 0.8764481350030136
# Precision: 0.8744031830238727
# Recall: 0.8843954248366013
# ###########
#
#
# F1 Score: 0.8848930481283422
# Precision: 0.8833421610169492
# Recall: 0.8941993464052287
# ###########
#
#
# F1 Score: 0.9000541711809318
# Precision: 0.8982479784366577
# Recall: 0.9023692810457516
# ###########
#
#
# F1 Score: 0.8604604604604604
# Precision: 0.859920634920635
# Recall: 0.8705065359477124
# ###########

# %%
path_in = "./completions/mistral_7b/completion_promise_tfidf_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.6147875816993464
# Precision: 0.7301075268817204
# Recall: 0.6748366013071896
# ###########
#
#
# F1 Score: 0.5928192574459404
# Precision: 0.6031746031746031
# Recall: 0.5972222222222222
# ###########
#
#
# F1 Score: 0.5872929430451554
# Precision: 0.596403411197627
# Recall: 0.5906862745098039
# ###########
#
#
# F1 Score: 0.9342245989304813
# Precision: 0.9322033898305084
# Recall: 0.9444444444444444
# ###########
#
#
# F1 Score: 0.9097097097097098
# Precision: 0.9087301587301587
# Recall: 0.9207516339869282
# ###########
#
#
# F1 Score: 0.9500270855904658
# Precision: 0.947978436657682
# Recall: 0.9526143790849673
# ###########
#
#
# F1 Score: 0.9502695417789757
# Precision: 0.947192513368984
# Recall: 0.9554738562091503
# ###########

# %% [markdown]
# ## multi-class

# %%
path_in = "./completions/mistral_7b/completion_promise_random_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_random_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.20747850779943205
# Precision: 0.35730063383095423
# Recall: 0.21262254901960784
# ###########
#
#
# F1 Score: 0.19851576994434136
# Precision: 0.30395529052516346
# Recall: 0.18714152327597708
# ###########
#
#
# F1 Score: 0.20035473049548935
# Precision: 0.3014069264069264
# Recall: 0.1905617802676626
# ###########
#
#
# F1 Score: 0.261196546949723
# Precision: 0.3382414369256475
# Recall: 0.251437417072092
# ###########
#
#
# F1 Score: 0.29988290244598137
# Precision: 0.39398692810457514
# Recall: 0.2781771968046478
# ###########
#
#
# F1 Score: 0.3101300477871009
# Precision: 0.38800904977375567
# Recall: 0.2996759488108969
# ###########
#
#
# F1 Score: 0.29258658337150417
# Precision: 0.3673128342245989
# Recall: 0.28361069918163345
# ###########

# %%
path_in = "./completions/mistral_7b/completion_promise_embedding_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_embedding_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.20747850779943205
# Precision: 0.35730063383095423
# Recall: 0.21262254901960784
# ###########
#
#
# F1 Score: 0.29214899635067704
# Precision: 0.42481458304361935
# Recall: 0.28358750907770514
# ###########
#
#
# F1 Score: 0.3078085847269837
# Precision: 0.3982487246485007
# Recall: 0.28575851393188856
# ###########
#
#
# F1 Score: 0.3623041060427576
# Precision: 0.4820728291316526
# Recall: 0.3299610040094469
# ###########
#
#
# F1 Score: 0.3873051427738928
# Precision: 0.5136795408332151
# Recall: 0.3530345471521942
# ###########
#
#
# F1 Score: 0.3842172757742364
# Precision: 0.4893490537240538
# Recall: 0.35974556489262377
# ###########
#
#
# F1 Score: 0.3809116856940037
# Precision: 0.4902780920060332
# Recall: 0.3520424836601307
# ###########

# %%
path_in = "./completions/mistral_7b/completion_promise_tfidf_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_promise_tfidf_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.20747850779943205
# Precision: 0.35730063383095423
# Recall: 0.21262254901960784
# ###########
#
#
# F1 Score: 0.2863877380526145
# Precision: 0.36431466203502677
# Recall: 0.26932550798097016
# ###########
#
#
# F1 Score: 0.3745190201663416
# Precision: 0.46690307328605196
# Recall: 0.35894607843137255
# ###########
#
#
# F1 Score: 0.4681711970502486
# Precision: 0.5812858831475852
# Recall: 0.4454515139389089
# ###########
#
#
# F1 Score: 0.4333434958100273
# Precision: 0.5448072562358276
# Recall: 0.409760348583878
# ###########
#
#
# F1 Score: 0.36846886417150954
# Precision: 0.4868944636678201
# Recall: 0.3387378480804087
# ###########
#
#
# F1 Score: 0.32248180332739157
# Precision: 0.4124702380952381
# Recall: 0.297796451914099
# ###########

# %% [markdown]
# # nfr multi_class

# %%
path_in = "./completions/mistral_7b/completion_nfr_random_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_random_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.17045754926116338
# Precision: 0.2451543517021079
# Recall: 0.17516144550538965
# ###########
#
#
# F1 Score: 0.0379819175382552
# Precision: 0.058092174211825186
# Recall: 0.04058285465777654
# ###########
#
#
# F1 Score: 0.03423458214658004
# Precision: 0.0484802086187867
# Recall: 0.036479442145246475
# ###########
#
#
# F1 Score: 0.045571688798300466
# Precision: 0.062314166038916007
# Recall: 0.04905527206405109
# ###########
#
#
# F1 Score: 0.05551529933084444
# Precision: 0.07343842057628916
# Recall: 0.05847690866451491
# ###########
#
#
# F1 Score: 0.052839901908537545
# Precision: 0.06993195101938643
# Recall: 0.05531074316760146
# ###########
#
#
# F1 Score: 0.07653496117143492
# Precision: 0.09750190208843455
# Recall: 0.08142550519189616
# ###########

# %%
path_in = "./completions/mistral_7b/completion_nfr_embedding_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_embedding_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.17067529047173818
# Precision: 0.24550246044368032
# Recall: 0.17530173873324045
# ###########
#
#
# F1 Score: 0.04766941681253569
# Precision: 0.06643177655359575
# Recall: 0.050442107186692314
# ###########
#
#
# F1 Score: 0.05038170669738344
# Precision: 0.06701306102781056
# Recall: 0.05410677309182245
# ###########
#
#
# F1 Score: 0.0643928753662831
# Precision: 0.08309534316463708
# Recall: 0.06795898850268399
# ###########
#
#
# F1 Score: 0.08952398918793152
# Precision: 0.11288544987831634
# Recall: 0.0934708943943073
# ###########
#
#
# F1 Score: 0.0936094617377932
# Precision: 0.1177291140521953
# Recall: 0.09686323013900798
# ###########
#
#
# F1 Score: 0.07611318188810931
# Precision: 0.09543470400393474
# Recall: 0.0777751898336479
# ###########

# %%
path_in = "./completions/mistral_7b/completion_nfr_tfidf_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)

path_in = "./completions/mistral_7b/completion_nfr_tfidf_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
get_evaluation_results(ground_truth, processed_completion_list)
# Out:
# F1 Score: 0.17054017587130138
# Precision: 0.24542727234640108
# Recall: 0.17512730998738313
# ###########
#
#
# F1 Score: 0.033300439917668165
# Precision: 0.04552358326945798
# Recall: 0.035743072720534765
# ###########
#
#
# F1 Score: 0.0391326578549766
# Precision: 0.05327125939213051
# Recall: 0.04202061694528259
# ###########
#
#
# F1 Score: 0.04022127981416714
# Precision: 0.0521009788185278
# Recall: 0.04190627012877596
# ###########
#
#
# F1 Score: 0.0904487076399615
# Precision: 0.11198438428857355
# Recall: 0.09444129917834729
# ###########
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 35
#      33 path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
#      34 ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
# ---> 35 get_evaluation_results(ground_truth, processed_completion_list)
#      37 path_in = "./completions/mistral_7b/completion_nfr_tfidf_160.txt"
#      38 processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
#
# File ~/Desktop/tang/code/re_genai/get_completion_evaluation.py:49, in get_evaluation_results(ground_truth, processed_completion_list)
#      44 """input
#      45     ground_truth: list, true requirement classifications
#      46     processed_completion_list: list, completions from LLMs
#      47 """
#      48 # Calculate precision, recall, and F1 score
# ---> 49 precision = precision_score(ground_truth, processed_completion_list, zero_division = True, average='macro')
#      50 recall = recall_score(ground_truth, processed_completion_list, zero_division = 0, average='macro')
#      51 f1 = f1_score(ground_truth, processed_completion_list, average='macro')
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2204, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2037 @validate_params(
#    2038     {
#    2039         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2064     zero_division="warn",
#    2065 ):
#    2066     """Compute the precision.
#    2067
#    2068     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2202     array([0.5, 1. , 1. ])
#    2203     """
# -> 2204     p, _, _, _ = precision_recall_fscore_support(
#    2205         y_true,
#    2206         y_pred,
#    2207         labels=labels,
#    2208         pos_label=pos_label,
#    2209         average=average,
#    2210         warn_for=("precision",),
#    2211         sample_weight=sample_weight,
#    2212         zero_division=zero_division,
#    2213     )
#    2214     return p
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1789, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1626 """Compute precision, recall, F-measure and support for each class.
#    1627
#    1628 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1786  array([2, 2, 2]))
#    1787 """
#    1788 _check_zero_division(zero_division)
# -> 1789 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1791 # Calculate tp_sum, pred_sum, true_sum ###
#    1792 samplewise = average == "samples"
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1561, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1558 if average not in average_options and average != "binary":
#    1559     raise ValueError("average has to be one of " + str(average_options))
# -> 1561 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1562 # Convert to Python primitive type to avoid NumPy type / Python str
#    1563 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1564 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:103, in _check_targets(y_true, y_pred)
#      76 """Check that y_true and y_pred belong to the same classification task.
#      77
#      78 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#     100 y_pred : array or indicator matrix
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred)
# --> 103 check_consistent_length(y_true, y_pred)
#     104 type_true = type_of_target(y_true, input_name="y_true")
#     105 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/Desktop/tang/code/re_genai/.env/lib/python3.10/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [3487, 2494]
