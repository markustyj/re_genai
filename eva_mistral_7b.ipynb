# %%
from get_completion_evaluation import read_completion_list

# %reload_ext autoreload
# %autoreload 2

# %%
path_in = "/Users/yongjiantang/Desktop/tang/code/re_genai/completions/mistral_7b/completion_promise_random_0_bi.txt"
completion_list = read_completion_list(path_in)
len(completion_list), completion_list
# Out:
# (123,
#  [' Functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional',
#   ' Non-functional',
#   " Non-functional (for the first part, as it pertains to the aesthetic aspect of the software, not its functionality. The second part can be considered a performance requirement under non-functional, as it quantifies user satisfaction with the interface's simplicity.)",
#   ' Functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional (Usability, Performance)',
#   ' Functional',
#   ' Non-functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
#   ' Non-functional',
#   ' Functional',
#   ' Functional',
#   ' Functional',
# ...

# %%
[completion.strip().split()[0] for completion in completion_list]
# Out:
# ['Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Non-functional',
#  'Non-functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Non-functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Non-functional',
#  'Functional',
#  'Functional',
#  'Functional',
#  'Functional',
# ...
