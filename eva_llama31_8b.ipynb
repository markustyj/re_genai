# %%
from get_completion_evaluation import read_completion_list, process_completion_list
from get_completion_evaluation import process_ground_truth_list, load_csv_for_evaluation, get_evaluation_results, plot_value

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # promise random binary

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_random_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.8125621148876963
# Precision: 0.8209728867623605
# Recall: 0.8288398692810457
# ###########
#
#
# F1 Score: 0.8587639311043567
# Precision: 0.856682769726248
# Recall: 0.8619281045751634
# ###########
#
#
# F1 Score: 0.8673854447439353
# Precision: 0.8649732620320856
# Recall: 0.8717320261437909
# ###########
#
#
# F1 Score: 0.8844605475040257
# Precision: 0.8819776714513556
# Recall: 0.8913398692810457
# ###########
#
#
# F1 Score: 0.8643132928847215
# Precision: 0.870380739081747
# Recall: 0.8602941176470589
# ###########
#
#
# F1 Score: 0.8553241541548467
# Precision: 0.8633540372670807
# Recall: 0.8504901960784313
# ###########
#
#
# F1 Score: 0.5611928642897235
# Precision: 0.5946623093681916
# Recall: 0.5482026143790849
# ###########

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_embedding_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.812810163435453
# Precision: 0.825668449197861
# Recall: 0.8316993464052287
# ###########
#
#
# F1 Score: 0.874736913571865
# Precision: 0.8737811484290358
# Recall: 0.8758169934640523
# ###########
#
#
# F1 Score: 0.9255698245142203
# Precision: 0.9225746268656716
# Recall: 0.931781045751634
# ###########
#
#
# F1 Score: 0.924842148143119
# Precision: 0.9237540628385699
# Recall: 0.926062091503268
# ###########
#
#
# F1 Score: 0.9333694474539544
# Precision: 0.9314016172506738
# Recall: 0.9358660130718954
# ###########
#
#
# F1 Score: 0.6138155482214889
# Precision: 0.6168518518518519
# Recall: 0.6108387799564271
# ###########
#
#
# F1 Score: 0.30445075757575757
# Precision: 0.47777777777777775
# Recall: 0.2565359477124183
# ###########

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_tfidf_0_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_5_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_10_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_20_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_40_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_80_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_160_bi.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = True )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.812810163435453
# Precision: 0.825668449197861
# Recall: 0.8316993464052287
# ###########
#
#
# F1 Score: 0.924842148143119
# Precision: 0.9237540628385699
# Recall: 0.926062091503268
# ###########
#
#
# F1 Score: 0.9167118093174431
# Precision: 0.9148247978436658
# Recall: 0.9191176470588235
# ###########
#
#
# F1 Score: 0.9333694474539544
# Precision: 0.9314016172506738
# Recall: 0.9358660130718954
# ###########
#
#
# F1 Score: 0.915195808052951
# Precision: 0.9220324748040314
# Recall: 0.9105392156862746
# ###########
#
#
# F1 Score: 0.9255698245142203
# Precision: 0.9225746268656716
# Recall: 0.931781045751634
# ###########
#
#
# F1 Score: 0.45622435020519836
# Precision: 0.4852941176470588
# Recall: 0.4332107843137255
# ###########

# %% [markdown]
# ## multi-class

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_random_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_random_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.31941098775776194
# Precision: 0.4919190315005673
# Recall: 0.32317927170868344
# ###########
#
#
# F1 Score: 0.3982405462184874
# Precision: 0.54654244176303
# Recall: 0.3848039215686274
# ###########
#
#
# F1 Score: 0.42695094264328387
# Precision: 0.5944297138047138
# Recall: 0.4258636788048553
# ###########
#
#
# F1 Score: 0.42108173235624213
# Precision: 0.5880621693121694
# Recall: 0.4429271708683473
# ###########
#
#
# F1 Score: 0.4564829192546584
# Precision: 0.5779528478057889
# Recall: 0.4781512605042017
# ###########
#
#
# F1 Score: 0.4197473936563121
# Precision: 0.5428517560870503
# Recall: 0.42704158586511526
# ###########
#
#
# F1 Score: 0.33795161827419895
# Precision: 0.6100668562207023
# Recall: 0.31139122315592904
# ###########

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_embedding_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_embedding_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.31941098775776194
# Precision: 0.4919190315005673
# Recall: 0.32317927170868344
# ###########
#
#
# F1 Score: 0.5587182467884575
# Precision: 0.6782352941176472
# Recall: 0.5614098972922502
# ###########
#
#
# F1 Score: 0.6249979776916923
# Precision: 0.7446527123435186
# Recall: 0.6250606909430438
# ###########
#
#
# F1 Score: 0.6027382135649959
# Precision: 0.7155486024196913
# Recall: 0.6083940242763772
# ###########
#
#
# F1 Score: 0.5870075093778369
# Precision: 0.7310317878983256
# Recall: 0.5786775316187082
# ###########
#
#
# F1 Score: 0.39525145906724857
# Precision: 0.6459540459540458
# Recall: 0.3441786971198736
# ###########
#
#
# F1 Score: 0.1789141414141414
# Precision: 0.7222222222222222
# Recall: 0.11834733893557425
# ###########

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_promise_tfidf_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_promise_tfidf_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_promise_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.31941098775776194
# Precision: 0.4919190315005673
# Recall: 0.32317927170868344
# ###########
#
#
# F1 Score: 0.5943520246452798
# Precision: 0.7258661040173645
# Recall: 0.5801205330617095
# ###########
#
#
# F1 Score: 0.5973788577014383
# Precision: 0.7094362745098038
# Recall: 0.6106162464985995
# ###########
#
#
# F1 Score: 0.6081833109419316
# Precision: 0.7136519607843137
# Recall: 0.6234733893557423
# ###########
#
#
# F1 Score: 0.6256581256581257
# Precision: 0.7486728184096605
# Recall: 0.6345845004668534
# ###########
#
#
# F1 Score: 0.5388628520658763
# Precision: 0.7608766233766233
# Recall: 0.5152788388082506
# ###########
#
#
# F1 Score: 0.34910569376820294
# Precision: 0.7143058491895701
# Recall: 0.29186118892001245
# ###########

# %% [markdown]
# # nfr multi_class

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_nfr_random_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_random_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.2035836930053751
# Precision: 0.2813023570816251
# Recall: 0.2059938099179785
# ###########
#
#
# F1 Score: 0.24190745335718447
# Precision: 0.32649245473659677
# Recall: 0.26214355852818094
# ###########
#
#
# F1 Score: 0.35822756725841154
# Precision: 0.4678901021781364
# Recall: 0.3645097276083041
# ###########
#
#
# F1 Score: 0.3514517165901121
# Precision: 0.429661589333012
# Recall: 0.36920370339335823
# ###########
#
#
# F1 Score: 0.37752831192894704
# Precision: 0.46680988369682797
# Recall: 0.4029814977039577
# ###########
#
#
# F1 Score: 0.29592659954201067
# Precision: 0.37327619138745644
# Recall: 0.31322214354997513
# ###########
#
#
# F1 Score: 0.25890019129103226
# Precision: 0.40302473828448543
# Recall: 0.25887228289072983
# ###########

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_nfr_embedding_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_embedding_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_embedding_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_embedding_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_embedding_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_embedding_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

# path_in = "./completions/llama31_8b/completion_nfr_embedding_160.txt"
# processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
# path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
# ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
# get_evaluation_results(ground_truth, processed_completion_list)
print("160 inavailable")
# Out:
# F1 Score: 0.203967085595281
# Precision: 0.28163408854657807
# Recall: 0.20628668431687944
# ###########
#
#
# F1 Score: 0.3662421366985668
# Precision: 0.46153069206107417
# Recall: 0.35761869395327134
# ###########
#
#
# F1 Score: 0.3735474581836389
# Precision: 0.46918282370608067
# Recall: 0.3647764576878756
# ###########
#
#
# F1 Score: 0.4165868199689884
# Precision: 0.5191297530487882
# Recall: 0.40885060654389027
# ###########
#
#
# F1 Score: 0.30312292723023787
# Precision: 0.3767301532877061
# Recall: 0.30009637685033225
# ###########
#
#
# F1 Score: 0.303991490034693
# Precision: 0.38377552003563503
# Recall: 0.2964950120778393
# ###########
#
#
# 160 inavailable

# %%
f1_list = []

path_in = "./completions/llama31_8b/completion_nfr_tfidf_0.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_5.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_10.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_20.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_40.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_80.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

path_in = "./completions/llama31_8b/completion_nfr_tfidf_160.txt"
processed_completion_list = process_completion_list(  read_completion_list(path_in)  )
path_in_ground = "/Users/yongjiantang/Desktop/tang/code/re_genai/data/processed_nfr_so_test.csv"
ground_truth = process_ground_truth_list(  load_csv_for_evaluation(path_in_ground),  bi_classification = False )
f1, precision, recall = get_evaluation_results(ground_truth, processed_completion_list)
f1_list.append(f1)

plot_value(f1_list)
# Out:
# F1 Score: 0.20282805489074562
# Precision: 0.2806874615871402
# Recall: 0.20575510067046346
# ###########
#
#
# F1 Score: 0.3531523328044533
# Precision: 0.4460727680514675
# Recall: 0.3493437284789947
# ###########
#
#
# F1 Score: 0.4236509661037511
# Precision: 0.5390587352345341
# Recall: 0.4170910518989516
# ###########
#
#
# F1 Score: 0.4767398771008563
# Precision: 0.6035898400501071
# Recall: 0.4737057720579545
# ###########
#
#
# F1 Score: 0.5088001558045518
# Precision: 0.6310601074292804
# Recall: 0.5025684457181562
# ###########
#
#
# F1 Score: 0.4266652423052833
# Precision: 0.528618255908552
# Recall: 0.4212179495234864
# ###########
#
#
# F1 Score: 0.28491275105662595
# Precision: 0.3652135689102918
# Recall: 0.27444391882119323
# ###########
