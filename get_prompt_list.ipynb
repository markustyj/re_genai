# %%
import csv
from prompt_construction import get_all_prompt, save_prompt_list, read_prompt_list

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## test whether get_all_prompt() works

# %%
dataset = "promise"
method = "embedding"
num_shot = 5
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)

# %%
for i in range (8):
    print(prompt_list[i] + "\n\n")
# Out:
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The website shall be available for use 24 hours per day 365 days per year.': Non-functional
# 'The product shall provide Monitoring Services.The product shall be easy for System Administrators and DBAs to use after two weeks of usage.': Non-functional
# 'The product shall be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product shall be available 99.99% of the time for regular business days.': Non-functional
# 'The product shall be expected to operate for at least 5 years for each customer installation.': Non-functional
# 'The product shall be able to be installed in the specified environment within 1 working day.': Non-functional
# Classify the given requirement: 'The product shall be available for use 24 hours per day 365 days per year'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The Disputes application shall ensure that only users with the appropriate access level are allowed to initiate dispute requests.': Non-functional
# 'The Disputes System shall provide update access capability for authorized users of the application.': Functional
# 'The Disputes application shall ensure that only authorized users are allowed to logon to the application.': Non-functional
# 'All updates to data files or database must be initiated from the Disputes System.': Non-functional
# 'Only authorized users shall have access to the portion of the system that interfaces with CampusConnect.': Non-functional
# Classify the given requirement: 'Only users with Update access must be able to initiate dispute requests.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The user shall select to view the preferred repair facility ratings.': Functional
# 'The system shall locate the preferred repair facility with the highest ratings for the input criteria': Functional
# 'The current repair facility ratings shall be displayed to the user.': Functional
# 'The preferred repair facility shall be returned to the user.': Functional
# 'The preferred repair facility ratings shall be saved within 5 seconds. The save shall occur within 5 seconds.': Non-functional
# Classify the given requirement: 'The user shall select to save the preferred repair facility ratings.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The system shall contain contact information (e-mail and phone number) for all people relevant to the system including (but not limited to) staff members students lecture instructors clinical lab instructors and clinical site administrators.': Functional
# 'The system shall use IBM and CCR branding standards. The interface must have one IBM logo and one CCR logo.': Non-functional
# 'The system shall be used within the specifications defined by the computers used by the Program Administrators/Nursing Staff Members.': Non-functional
# 'The intranet pages should display appropriately in all resolutions from 800x600 and higher. The display of all the pages will be correct in 95% of the resolutions prior to implementation. The remaining 5% will be corrected within a week of notification of the incorrect display.': Non-functional
# 'Any interface between a user and the automated system shall have a maximum response time of 5 seconds unless noted by an exception below.': Non-functional
# Classify the given requirement: 'The system shall be displayable on any work computer a CCR user may have. The system interface shall be formatted to display at 800 by 600 pixel resolution.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The system shall be used within the specifications defined by the computers used by the Program Administrators/Nursing Staff Members.': Non-functional
# 'The system shall contain contact information (e-mail and phone number) for all people relevant to the system including (but not limited to) staff members students lecture instructors clinical lab instructors and clinical site administrators.': Functional
# 'The system shall use symbols and words that are naturally understandable by the user community.': Non-functional
# 'Program Administrators/Nursing Staff Members shall be able to create a new Program of Study.': Functional
# 'Program Administrators and Nursing Staff Members shall have the ability to specify which classes are required for a Program of Study': Functional
# Classify the given requirement: 'The system shall be intuitive to the Program Administrators/Nursing Staff Members.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# '100% of cardmember services representatives shall be able to successfully create a dispute case on the first encounter after completing the training course.': Non-functional
# '100% of the cardmember and merchant services representatives shall use the Disputes application regularly after a 2-day training course.': Non-functional
# 'The Dispute System shall provide the users with the ability to follow up on a dispute case via follow-up actions. The list of available follow up actions for a given dispute case must be filtered by the status of the case and the access level of the user.': Functional
# 'The Disputes System must provide a confirmation to the user upon the creation of a chargeback request. The confirmation must contain the following information; the dispute case number the type of chargeback requested (pending or immediate) and the date that the merchant response is due.': Functional
# 'The Disputes System must provide the user the ability to initiate a single dispute case on multiple transactions that belong to a single merchant.': Functional
# Classify the given requirement: '100% of merchant services representatives shall be able to successfully perform a follow up action on a dispute case on the first encounter after completing the training course.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The product will be able to delete conference rooms.': Functional
# 'The product shall be able to store new room equipment.': Functional
# 'The product shall allow a user to remove himself or herself from the list of players at any time.': Functional
# 'The system shall allow a Program Administrator or Nursing staff member to remove a student from a clinical lab section.': Functional
# 'The product shall remove players who have been inactive for 24 hours from the list of players.': Functional
# Classify the given requirement: 'The product shall be able to delete room equipment.'
#
#
# Please classify the given software requirements into functional requirement or non-functional requirement. The answer should be in format {the given requirement: functional requirement or non-functional requirement}.
# Here are a few examples:
# 'The product shall be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product shall be available 99.99% of the time for regular business days.': Non-functional
# 'The language of the product shall accommodate all of the target market countries. 90% of survey respondents from each target market country will find that the language of the product is acceptable.': Non-functional
# 'The product shall make the users want to use it. 80% of the users surveyed report they are regularly using the product after the first 2 weeks post-launch.': Non-functional
# 'The product shall achieve a 98% uptime. The product shall not fail more than 2% of the available online time.': Non-functional
# 'The product must comply with the intranet page standards and requirements of ENET Securities. 95% of the product look & feel will be approved by the Architecture group prior to implementation. The remaining 5% will be corrected and approved within one month of product release.': Non-functional
# Classify the given requirement: 'The product shall be able to display calendar dates and times according to the user’s locale. 90% of survey respondents from each target market country will find that the date and time formatting of the product is correct.'

# %% [markdown]
# ## formally save the constructed prompts
# ## binary promise

# %%
dataset = "promise"
method = "random"
num_shot = 0
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_0_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 5
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_5_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 10
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_10_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 20
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_20_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 40
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_40_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 80
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_80_bi.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "random"
num_shot = 160
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_160_bi.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "embedding"
num_shot = 0
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_0_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 5
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_5_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 10
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_10_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 20
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_20_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 40
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_40_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 80
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_80_bi.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "embedding"
num_shot = 160
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_160_bi.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "tfidf"
num_shot = 0
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_0_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 5
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_5_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 10
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_10_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 20
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_20_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 40
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_40_bi.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 80
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_80_bi.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "tfidf"
num_shot = 160
bi_classification = True
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_160_bi.txt'
save_prompt_list(path, prompt_list)

# %% [markdown]
# ## multi-class promise

# %%
dataset = "promise"
method = "random"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_0.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_5.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_10.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_20.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_40.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "random"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "random"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_random_160.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "embedding"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_0.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_5.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_10.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_20.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_40.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "embedding"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "embedding"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_embedding_160.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "tfidf"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_0.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_5.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_10.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_20.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_40.txt'
save_prompt_list(path, prompt_list)

dataset = "promise"
method = "tfidf"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "promise"
method = "tfidf"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_promise_tfidf_160.txt'
save_prompt_list(path, prompt_list)

# %% [markdown]
# ### multi-class nfr_so

# %%
dataset = "nfr"
method = "random"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_0.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "random"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_5.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "random"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_10.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "random"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_20.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "random"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_40.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "random"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "nfr"
method = "random"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_random_160.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "nfr"
method = "embedding"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_0.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "embedding"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_5.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "embedding"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_10.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "embedding"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_20.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "embedding"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_40.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "embedding"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "nfr"
method = "embedding"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_embedding_160.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "nfr"
method = "tfidf"
num_shot = 0
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_0.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "tfidf"
num_shot = 5
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_5.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "tfidf"
num_shot = 10
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_10.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "tfidf"
num_shot = 20
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_20.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "tfidf"
num_shot = 40
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_40.txt'
save_prompt_list(path, prompt_list)

dataset = "nfr"
method = "tfidf"
num_shot = 80
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_80.txt'
save_prompt_list(path, prompt_list)

# %%
dataset = "nfr"
method = "tfidf"
num_shot = 160
bi_classification = False
prompt_list = get_all_prompt( dataset, method, num_shot, bi_classification)
path = './processed_prompts/prompt_nfr_tfidf_160.txt'
save_prompt_list(path, prompt_list)
